# %% [markdown]
# Note: Utilize this Jupiter Notebook (End_Term_MLP.ipynb) file attached to perform the following tasks in Jupyter Notebook file. While submitting the file, the filename should be renamed as End_Term_MLP_<Name><Roll Number>.ipynb. The codes should be executed and the outputs should be visible. If the outputs are not present, the students will lose marks.

# %% [markdown]
# Q5.  The following set of questions can be answered using the dataset (classify_strains.csv) attached.

# %%
#Loading appropriate packages

import pandas as pd
import numpy as np

# For OS related operations
import os
import matplotlib.pyplot as plt
import seaborn as sns

# Scale numeric data
from sklearn.preprocessing import StandardScaler as ss

# One hot encode data--Convert to dummy
from sklearn.preprocessing import OneHotEncoder as ohe

from sklearn.preprocessing import LabelEncoder

# for data splitting
from sklearn.model_selection import train_test_split


#Reading the complete data
from sklearn.tree import DecisionTreeClassifier 
from sklearn import tree
###################### Random Forest ############################
from sklearn.ensemble import RandomForestClassifier 

######### kNN ##############
from sklearn.neighbors import KNeighborsClassifier



from sklearn.metrics import classification_report

# %% [markdown]
# Q5a. Read the file "classify_strains.csv" and check if the file is loaded properly by checking the last 3 rows.  [2 marks]

# %%
df = pd.read_csv('classify_strains.csv')

# %%
df.tail(3)
# Out:
#     Gender Transmissibility Impact_Chance  Potassium_content
# 197      M           NORMAL          HIGH              9.894
# 198      M           NORMAL        NORMAL             14.020
# 199      F              LOW        NORMAL             11.349

# %% [markdown]
# Q5b. Check the dimensions of the dataframe (rows and columns).           [1 mark]

# %%
df
# Out:
#     Gender Transmissibility Impact_Chance  Potassium_content
# 0        F             HIGH          HIGH             25.355
# 1        M              LOW          HIGH             13.093
# 2        M              LOW          HIGH             10.114
# 3        F           NORMAL          HIGH              7.798
# 4        F              LOW          HIGH             18.043
# ..     ...              ...           ...                ...
# 195      F              LOW          HIGH             11.567
# 196      M              LOW          HIGH             12.006
# 197      M           NORMAL          HIGH              9.894
# 198      M           NORMAL        NORMAL             14.020
# 199      F              LOW        NORMAL             11.349
#
# [200 rows x 4 columns]

# %%
# Run this set of codes. Do not change anything in this code
import random
randlist = [np.NaN]
for i in range(0,80):
    n = random.randint(18,95)
    randlist.append(n)
print(randlist)

age = []
for i in range(0,200):
    n=""
    for j in randlist:
        n = random.choice(randlist)
    age.append(n)
print(age)
print(len(age))
# Out:
# [nan, 63, 63, 78, 30, 43, 36, 52, 83, 42, 67, 86, 22, 55, 75, 38, 27, 87, 43, 55, 51, 55, 49, 43, 75, 31, 22, 26, 61, 89, 27, 40, 48, 45, 91, 86, 69, 91, 54, 85, 33, 25, 77, 35, 38, 51, 59, 19, 84, 65, 76, 34, 66, 58, 33, 90, 73, 71, 89, 26, 83, 63, 95, 46, 20, 39, 39, 56, 19, 53, 84, 89, 22, 39, 37, 82, 22, 90, 64, 82, 64]
# [26, 51, 76, 89, 78, 31, 75, 64, 22, 59, nan, 55, 77, 66, 91, 30, 64, 84, 27, 87, 19, 20, 34, 84, 31, 75, 59, 35, 82, 22, 75, 22, 38, 63, 30, 19, 40, 65, 39, 19, 27, 64, 43, 31, 26, 43, 84, 64, 19, 83, 55, 59, 63, 86, 43, 49, 49, 61, 49, 26, 51, 63, 22, 64, 86, 52, 61, 58, 27, 77, 27, 64, 19, 26, 58, 19, 75, 87, 43, 83, 36, 89, 38, 55, 48, 85, 37, 75, 22, 95, 39, 22, 43, 36, 19, 83, 33, 43, 58, 39, 91, 33, 19, 39, 56, 49, 76, 64, 39, 87, 89, 86, 45, 56, 89, 31, 49, 61, 33, 76, 52, 95, 64, 51, 84, 54, 90, 55, 59, 35, 55, 36, 43, 83, 19, 19, 22, 77, 45, 77, 82, 20, 51, 39, 26, 20, 86, 45, 63, 36, 86, 71, 31, 89, 35, 46, 35, 75, 75, 39, 69, 64, 83, 89, 86, 39, 48, 82, 84, 19, 86, 55, 30, 45, 22, 65, 82, 75, 90, 38, 26, 90, 58, 69, 33, 89, 37, 84, 65, 38, 22, 38, 95, 22, 91, 89, 39, 39, 27, 75]
# 200

# %% [markdown]
# Q5c. Add a new column in the dataframe named "Age" containing the values in the "age" array created above. Check if its correctly loaded.    [2 marks]

# %%
df['Age'] = age
df
# Out:
#     Gender Transmissibility Impact_Chance  Potassium_content   Age
# 0        F             HIGH          HIGH             25.355  73.0
# 1        M              LOW          HIGH             13.093  81.0
# 2        M              LOW          HIGH             10.114  54.0
# 3        F           NORMAL          HIGH              7.798  38.0
# 4        F              LOW          HIGH             18.043  61.0
# ..     ...              ...           ...                ...   ...
# 195      F              LOW          HIGH             11.567  67.0
# 196      M              LOW          HIGH             12.006  93.0
# 197      M           NORMAL          HIGH              9.894  65.0
# 198      M           NORMAL        NORMAL             14.020  32.0
# 199      F              LOW        NORMAL             11.349  26.0
#
# [200 rows x 5 columns]

# %% [markdown]
# Read this question carefully. Where ever you will find <RollNo> replace it with your own roll number and run the below given code. For Example, if its written like, "<RollNo>_X" and your roll number if "F894" it should be replaced as "F894_X"

# %%
#Execute the code given below
list1 = ["301166_X", "301166_Y", "301166_Z", "301166_A"] #<RollNo> should be replaced with your roll number
strain_class = []
for i in range(0,200):
    n=""
    for j in list1:
        n = random.choice(list1)
    strain_class.append(n)
print(strain_class)
print(len(strain_class))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_11876/4218902638.py in <module>
#       5     n=""
#       6     for j in list1:
# ----> 7         n = random.choice(list1)
#       8     strain_class.append(n)
#       9 print(strain_class)
#
# NameError: name 'random' is not defined

# %% [markdown]
# Q5d. Add a new column in the dataframe named "Strain_Class" containing the values in the "strain_class" array created above. Check if its correctly loaded.    [2 marks]

# %%
df['Strain_Class'] = strain_class
df
# Out:
#     Gender Transmissibility Impact_Chance  Potassium_content   Age  \
# 0        F             HIGH          HIGH             25.355  73.0
# 1        M              LOW          HIGH             13.093  81.0
# 2        M              LOW          HIGH             10.114  54.0
# 3        F           NORMAL          HIGH              7.798  38.0
# 4        F              LOW          HIGH             18.043  61.0
# ..     ...              ...           ...                ...   ...
# 195      F              LOW          HIGH             11.567  67.0
# 196      M              LOW          HIGH             12.006  93.0
# 197      M           NORMAL          HIGH              9.894  65.0
# 198      M           NORMAL        NORMAL             14.020  32.0
# 199      F              LOW        NORMAL             11.349  26.0
#
#     Strain_Class
# 0       301161_Y
# 1       301161_X
# 2       301161_A
# 3       301161_A
# 4       301161_A
# ..           ...
# 195     301161_Y
# 196     301161_A
# 197     301161_Z
# 198     301161_Y
# 199     301161_A
#
# [200 rows x 6 columns]

# %% [markdown]
# Q5e. Check if there are any missing values in the data. If there are missing values remove them (omission).    [2 marks]

# %%
df.isnull().sum()
df = df.replace(['?'],'NaN')
df.dropna(axis=0, inplace=True)
df.isnull().sum()
# Out:
# Gender               0
# Transmissibility     0
# Impact_Chance        0
# Potassium_content    0
# Age                  0
# Strain_Class         0
# dtype: int64

# %% [markdown]
# Q5f. Group the Age column into different age groups using 3 bins ("young","middle-aged","aged"). Name the column as "Age_cat" (Utilize the function 'cut' in pandas)     [3 marks]

# %%
df['Age_cat'] = pd.cut(df['Age'], bins = 3 , labels=["young", "middle-aged", "aged"])
df
# Out:
#     Gender Transmissibility Impact_Chance  Potassium_content   Age  \
# 0        F             HIGH          HIGH             25.355  73.0
# 1        M              LOW          HIGH             13.093  81.0
# 2        M              LOW          HIGH             10.114  54.0
# 3        F           NORMAL          HIGH              7.798  38.0
# 4        F              LOW          HIGH             18.043  61.0
# ..     ...              ...           ...                ...   ...
# 195      F              LOW          HIGH             11.567  67.0
# 196      M              LOW          HIGH             12.006  93.0
# 197      M           NORMAL          HIGH              9.894  65.0
# 198      M           NORMAL        NORMAL             14.020  32.0
# 199      F              LOW        NORMAL             11.349  26.0
#
#     Strain_Class      Age_cat
# 0       301161_Y         aged
# 1       301161_X         aged
# 2       301161_A  middle-aged
# 3       301161_A        young
# 4       301161_A  middle-aged
# ..           ...          ...
# 195     301161_Y  middle-aged
# 196     301161_A         aged
# 197     301161_Z  middle-aged
# 198     301161_Y        young
# 199     301161_A        young
#
# [192 rows x 7 columns]

# %% [markdown]
# Q5g. Remove the column "Age".       [1 mark]

# %%
df1 = df.drop(["Age"], axis =1)
df1
# Out:
#     Gender Transmissibility Impact_Chance  Potassium_content Strain_Class  \
# 0        F             HIGH          HIGH             25.355     301161_Y
# 1        M              LOW          HIGH             13.093     301161_X
# 2        M              LOW          HIGH             10.114     301161_A
# 3        F           NORMAL          HIGH              7.798     301161_A
# 4        F              LOW          HIGH             18.043     301161_A
# ..     ...              ...           ...                ...          ...
# 195      F              LOW          HIGH             11.567     301161_Y
# 196      M              LOW          HIGH             12.006     301161_A
# 197      M           NORMAL          HIGH              9.894     301161_Z
# 198      M           NORMAL        NORMAL             14.020     301161_Y
# 199      F              LOW        NORMAL             11.349     301161_A
#
#          Age_cat
# 0           aged
# 1           aged
# 2    middle-aged
# 3          young
# 4    middle-aged
# ..           ...
# 195  middle-aged
# 196         aged
# 197  middle-aged
# 198        young
# 199        young
#
# [192 rows x 6 columns]

# %% [markdown]
# Q5h. Standardize/Normalize the numeric column(s) and encode the categorical columns. The target variable (Strain_Class) should be label encoded.     [6 marks]

# %%
# label_encoder object
label_encoder =LabelEncoder()
# Encode labels in column. 
df1['Strain_Class']= label_encoder.fit_transform(df1['Strain_Class'])
df1.head(10)
# Out:
#    Gender Transmissibility Impact_Chance  Potassium_content  Strain_Class  \
# 0       F             HIGH          HIGH             25.355             2
# 1       M              LOW          HIGH             13.093             1
# 2       M              LOW          HIGH             10.114             0
# 3       F           NORMAL          HIGH              7.798             0
# 4       F              LOW          HIGH             18.043             0
# 5       F           NORMAL          HIGH              8.607             0
# 7       M              LOW          HIGH             11.037             3
# 8       M           NORMAL          HIGH             15.171             0
# 9       M              LOW        NORMAL             19.368             0
# 10      F              LOW          HIGH             11.767             1
#
#         Age_cat
# 0          aged
# 1          aged
# 2   middle-aged
# 3         young
# 4   middle-aged
# 5   middle-aged
# 7          aged
# 8          aged
# 9   middle-aged
# 10        young

# %% [markdown]
# Q5i. Form a heatmap to visualize correlation between different columns. State your interpretation.              [4 marks]

# %%
df1_corr = df1.corr()
df1_corr
sns.heatmap(df1_corr)
# Out:
# <AxesSubplot:>

# %% [markdown]
# Q5j. Create a bar-graph/column chart to figure out how many people belong to each age category.        [3 marks]

# %%
df1
# Out:
#     Gender Transmissibility Impact_Chance  Potassium_content  Strain_Class  \
# 0        F             HIGH          HIGH             25.355             2
# 1        M              LOW          HIGH             13.093             1
# 2        M              LOW          HIGH             10.114             0
# 3        F           NORMAL          HIGH              7.798             0
# 4        F              LOW          HIGH             18.043             0
# ..     ...              ...           ...                ...           ...
# 195      F              LOW          HIGH             11.567             2
# 196      M              LOW          HIGH             12.006             0
# 197      M           NORMAL          HIGH              9.894             3
# 198      M           NORMAL        NORMAL             14.020             2
# 199      F              LOW        NORMAL             11.349             0
#
#          Age_cat
# 0           aged
# 1           aged
# 2    middle-aged
# 3          young
# 4    middle-aged
# ..           ...
# 195  middle-aged
# 196         aged
# 197  middle-aged
# 198        young
# 199        young
#
# [192 rows x 6 columns]

# %% [markdown]
# Q5k. Place the independent variables in X. Place the dependent variable (strain_class) in Y. Then split the dataset into training and testing parts (80% training; 20% testing).                       [3 marks]

# %% [markdown]
# Q5l. Utilize RandomForest and kNN to build the classification model. Based on F-measure/F1-score and Accuracy determine which model is better.								                                                    [4+4+2=10]

# %% [markdown]
# Q5m. Taking the last digit of your roll number (If your roll number is '025001', the last digit is 1. If the last digit value is greater than 5, then consider the value as 4) as the number of components, do a Principal Component Analysis (PCA) on the same data. Create a RandomForestClassifier on the transformed data and check if there is any improvement of performance.                           [5 marks]
