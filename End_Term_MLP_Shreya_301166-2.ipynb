# %% [markdown]
# Note: Utilize this Jupiter Notebook (End_Term_MLP.ipynb) file attached to perform the following tasks in Jupyter Notebook file. While submitting the file, the filename should be renamed as End_Term_MLP_<Name><Roll Number>.ipynb. The codes should be executed and the outputs should be visible. If the outputs are not present, the students will lose marks.

# %% [markdown]
# Q5.  The following set of questions can be answered using the dataset (classify_strains.csv) attached.

# %%
#Loading appropriate packages

import pandas as pd
import numpy as np

# For OS related operations
import os
import matplotlib.pyplot as plt
import seaborn as sns

# Scale numeric data
from sklearn.preprocessing import StandardScaler as ss

# One hot encode data--Convert to dummy
from sklearn.preprocessing import OneHotEncoder as ohe

from sklearn.preprocessing import LabelEncoder

# for data splitting
from sklearn.model_selection import train_test_split


#Reading the complete data
from sklearn.tree import DecisionTreeClassifier 
from sklearn import tree
###################### Random Forest ############################
from sklearn.ensemble import RandomForestClassifier 

######### kNN ##############
from sklearn.neighbors import KNeighborsClassifier



from sklearn.metrics import classification_report

# %% [markdown]
# Q5a. Read the file "classify_strains.csv" and check if the file is loaded properly by checking the last 3 rows.  [2 marks]

# %%
df = pd.read_csv('classify_strains.csv')

# %%
df.tail(3)
# Out:
#     Gender Transmissibility Impact_Chance  Potassium_content
# 197      M           NORMAL          HIGH              9.894
# 198      M           NORMAL        NORMAL             14.020
# 199      F              LOW        NORMAL             11.349

# %% [markdown]
# Q5b. Check the dimensions of the dataframe (rows and columns).           [1 mark]

# %%
df
# Out:
#     Gender Transmissibility Impact_Chance  Potassium_content
# 0        F             HIGH          HIGH             25.355
# 1        M              LOW          HIGH             13.093
# 2        M              LOW          HIGH             10.114
# 3        F           NORMAL          HIGH              7.798
# 4        F              LOW          HIGH             18.043
# ..     ...              ...           ...                ...
# 195      F              LOW          HIGH             11.567
# 196      M              LOW          HIGH             12.006
# 197      M           NORMAL          HIGH              9.894
# 198      M           NORMAL        NORMAL             14.020
# 199      F              LOW        NORMAL             11.349
#
# [200 rows x 4 columns]

# %%
# Run this set of codes. Do not change anything in this code
import random
randlist = [np.NaN]
for i in range(0,80):
    n = random.randint(18,95)
    randlist.append(n)
print(randlist)

age = []
for i in range(0,200):
    n=""
    for j in randlist:
        n = random.choice(randlist)
    age.append(n)
print(age)
print(len(age))
# Out:
# [nan, 79, 87, 38, 83, 39, 41, 28, 77, 90, 55, 54, 87, 90, 62, 76, 65, 73, 62, 95, 54, 92, 49, 42, 25, 69, 52, 18, 77, 56, 38, 21, 42, 85, 32, 93, 29, 73, 84, 50, 49, 59, 84, 39, 40, 87, 63, 88, 26, 37, 40, 72, 87, 65, 50, 95, 37, 58, 37, 44, 20, 52, 78, 46, 46, 80, 31, 52, 46, 72, 54, 78, 92, 94, 60, 59, 40, 41, 24, 21, 18]
# [26, 65, 78, 59, 40, 49, 40, 50, 87, 92, 21, 87, 92, 58, 41, 90, 87, 28, 44, 44, 78, 65, 63, 87, 52, 80, 80, 95, 24, 37, 88, 62, 20, 93, 41, 26, 42, 95, 90, 40, 92, 29, 78, 79, 54, 65, 29, 92, 37, 52, 41, 73, 83, 58, 94, 26, 50, 40, 21, 37, 49, 18, 49, 73, 80, 31, 62, 79, 78, 32, 63, 38, 38, 29, 18, 60, 92, 59, 95, 87, 59, 42, 39, 38, 37, 25, 46, 73, 80, 87, 46, 39, 39, 20, 38, 37, 31, 39, 94, 46, 24, 56, 42, 52, 87, 84, 42, 39, 56, 87, 92, 21, 49, 59, 49, 54, 65, 65, 39, 52, 83, 62, 95, 38, 40, 44, 39, 77, nan, 79, 59, 50, 37, 90, 65, 58, 59, 54, 42, 38, 31, 55, 49, 55, 78, 39, 52, 65, 87, 52, 46, 78, 76, 40, 77, 94, 40, 38, 46, 83, 83, 40, 77, 73, 37, 25, 87, 54, 87, 38, 94, 94, 78, 37, 72, 83, 24, 60, 95, 18, 46, 95, 46, 24, 38, 40, 21, 18, 37, 60, 92, 26, 39, 87, 20, 24, 92, 95, 37, 42]
# 200

# %% [markdown]
# Q5c. Add a new column in the dataframe named "Age" containing the values in the "age" array created above. Check if its correctly loaded.    [2 marks]

# %%
df['Age'] = age
df
# Out:
#     Gender Transmissibility Impact_Chance  Potassium_content   Age
# 0        F             HIGH          HIGH             25.355  26.0
# 1        M              LOW          HIGH             13.093  65.0
# 2        M              LOW          HIGH             10.114  78.0
# 3        F           NORMAL          HIGH              7.798  59.0
# 4        F              LOW          HIGH             18.043  40.0
# ..     ...              ...           ...                ...   ...
# 195      F              LOW          HIGH             11.567  24.0
# 196      M              LOW          HIGH             12.006  92.0
# 197      M           NORMAL          HIGH              9.894  95.0
# 198      M           NORMAL        NORMAL             14.020  37.0
# 199      F              LOW        NORMAL             11.349  42.0
#
# [200 rows x 5 columns]

# %% [markdown]
# Read this question carefully. Where ever you will find <RollNo> replace it with your own roll number and run the below given code. For Example, if its written like, "<RollNo>_X" and your roll number if "F894" it should be replaced as "F894_X"

# %%
#Execute the code given below
list1 = ["301166_X", "301166_Y", "301166_Z", "301166_A"] #<RollNo> should be replaced with your roll number
strain_class = []
for i in range(0,200):
    n=""
    for j in list1:
        n = random.choice(list1)
    strain_class.append(n)
print(strain_class)
print(len(strain_class))
# Out:
# ['301166_X', '301166_Z', '301166_Y', '301166_A', '301166_X', '301166_X', '301166_Z', '301166_X', '301166_Y', '301166_Z', '301166_Z', '301166_Y', '301166_Y', '301166_Y', '301166_Y', '301166_Z', '301166_Y', '301166_X', '301166_A', '301166_Y', '301166_X', '301166_Z', '301166_A', '301166_X', '301166_X', '301166_Z', '301166_Y', '301166_Z', '301166_Z', '301166_X', '301166_X', '301166_Z', '301166_A', '301166_X', '301166_A', '301166_X', '301166_X', '301166_Y', '301166_Y', '301166_Z', '301166_X', '301166_Y', '301166_X', '301166_A', '301166_X', '301166_Z', '301166_A', '301166_X', '301166_Y', '301166_Y', '301166_A', '301166_A', '301166_X', '301166_A', '301166_A', '301166_Z', '301166_X', '301166_X', '301166_Y', '301166_Y', '301166_A', '301166_A', '301166_Z', '301166_A', '301166_Y', '301166_Z', '301166_Z', '301166_Y', '301166_A', '301166_Y', '301166_X', '301166_Y', '301166_Z', '301166_Z', '301166_A', '301166_A', '301166_Y', '301166_X', '301166_Y', '301166_Y', '301166_Y', '301166_Z', '301166_A', '301166_Z', '301166_X', '301166_Z', '301166_Y', '301166_X', '301166_A', '301166_Y', '301166_Z', '301166_Z', '301166_X', '301166_A', '301166_Y', '301166_Y', '301166_X', '301166_X', '301166_A', '301166_A', '301166_Y', '301166_Y', '301166_X', '301166_A', '301166_X', '301166_A', '301166_A', '301166_X', '301166_Y', '301166_Y', '301166_Z', '301166_Z', '301166_Y', '301166_Y', '301166_X', '301166_Y', '301166_A', '301166_Z', '301166_Y', '301166_Z', '301166_X', '301166_X', '301166_Z', '301166_A', '301166_Y', '301166_Z', '301166_Y', '301166_X', '301166_Z', '301166_Z', '301166_Y', '301166_Z', '301166_X', '301166_Y', '301166_A', '301166_Y', '301166_A', '301166_Z', '301166_Z', '301166_Y', '301166_X', '301166_Y', '301166_Y', '301166_Y', '301166_Z', '301166_Y', '301166_Y', '301166_A', '301166_Z', '301166_Z', '301166_A', '301166_Z', '301166_X', '301166_A', '301166_Z', '301166_X', '301166_Y', '301166_X', '301166_Z', '301166_Y', '301166_Y', '301166_Y', '301166_Z', '301166_X', '301166_Z', '301166_X', '301166_X', '301166_Y', '301166_X', '301166_X', '301166_X', '301166_X', '301166_Z', '301166_X', '301166_Y', '301166_Y', '301166_Y', '301166_Z', '301166_A', '301166_Y', '301166_A', '301166_Z', '301166_A', '301166_X', '301166_Y', '301166_Y', '301166_X', '301166_A', '301166_X', '301166_X', '301166_Y', '301166_A', '301166_A', '301166_Y', '301166_Z', '301166_Y', '301166_X', '301166_Y', '301166_X', '301166_A']
# 200

# %% [markdown]
# Q5d. Add a new column in the dataframe named "Strain_Class" containing the values in the "strain_class" array created above. Check if its correctly loaded.    [2 marks]

# %%
df['Strain_Class'] = strain_class
df
# Out:
#     Gender Transmissibility Impact_Chance  Potassium_content   Age  \
# 0        F             HIGH          HIGH             25.355  26.0
# 1        M              LOW          HIGH             13.093  65.0
# 2        M              LOW          HIGH             10.114  78.0
# 3        F           NORMAL          HIGH              7.798  59.0
# 4        F              LOW          HIGH             18.043  40.0
# ..     ...              ...           ...                ...   ...
# 195      F              LOW          HIGH             11.567  24.0
# 196      M              LOW          HIGH             12.006  92.0
# 197      M           NORMAL          HIGH              9.894  95.0
# 198      M           NORMAL        NORMAL             14.020  37.0
# 199      F              LOW        NORMAL             11.349  42.0
#
#     Strain_Class
# 0       301166_X
# 1       301166_Z
# 2       301166_Y
# 3       301166_A
# 4       301166_X
# ..           ...
# 195     301166_Y
# 196     301166_X
# 197     301166_Y
# 198     301166_X
# 199     301166_A
#
# [200 rows x 6 columns]

# %% [markdown]
# Q5e. Check if there are any missing values in the data. If there are missing values remove them (omission).    [2 marks]

# %%
df.isnull().sum()
df = df.replace(['?'],'NaN')
df.dropna(axis=0, inplace=True)
df.isnull().sum()
# Out:
# Gender               0
# Transmissibility     0
# Impact_Chance        0
# Potassium_content    0
# Age                  0
# Strain_Class         0
# dtype: int64

# %% [markdown]
# Q5f. Group the Age column into different age groups using 3 bins ("young","middle-aged","aged"). Name the column as "Age_cat" (Utilize the function 'cut' in pandas)     [3 marks]

# %%
df['Age_cat'] = pd.cut(df['Age'], bins = 3 , labels=["young", "middle-aged", "aged"])
df
# Out:
#     Gender Transmissibility Impact_Chance  Potassium_content   Age  \
# 0        F             HIGH          HIGH             25.355  26.0
# 1        M              LOW          HIGH             13.093  65.0
# 2        M              LOW          HIGH             10.114  78.0
# 3        F           NORMAL          HIGH              7.798  59.0
# 4        F              LOW          HIGH             18.043  40.0
# ..     ...              ...           ...                ...   ...
# 195      F              LOW          HIGH             11.567  24.0
# 196      M              LOW          HIGH             12.006  92.0
# 197      M           NORMAL          HIGH              9.894  95.0
# 198      M           NORMAL        NORMAL             14.020  37.0
# 199      F              LOW        NORMAL             11.349  42.0
#
#     Strain_Class      Age_cat
# 0       301166_X        young
# 1       301166_Z  middle-aged
# 2       301166_Y         aged
# 3       301166_A  middle-aged
# 4       301166_X        young
# ..           ...          ...
# 195     301166_Y        young
# 196     301166_X         aged
# 197     301166_Y         aged
# 198     301166_X        young
# 199     301166_A        young
#
# [195 rows x 7 columns]

# %% [markdown]
# Q5g. Remove the column "Age".       [1 mark]

# %%
df1 = df.drop(["Age"], axis =1)
df1
# Out:
#     Gender Transmissibility Impact_Chance  Potassium_content Strain_Class  \
# 0        F             HIGH          HIGH             25.355     301166_X
# 1        M              LOW          HIGH             13.093     301166_Z
# 2        M              LOW          HIGH             10.114     301166_Y
# 3        F           NORMAL          HIGH              7.798     301166_A
# 4        F              LOW          HIGH             18.043     301166_X
# ..     ...              ...           ...                ...          ...
# 195      F              LOW          HIGH             11.567     301166_Y
# 196      M              LOW          HIGH             12.006     301166_X
# 197      M           NORMAL          HIGH              9.894     301166_Y
# 198      M           NORMAL        NORMAL             14.020     301166_X
# 199      F              LOW        NORMAL             11.349     301166_A
#
#          Age_cat
# 0          young
# 1    middle-aged
# 2           aged
# 3    middle-aged
# 4          young
# ..           ...
# 195        young
# 196         aged
# 197         aged
# 198        young
# 199        young
#
# [195 rows x 6 columns]

# %% [markdown]
# Q5h. Standardize/Normalize the numeric column(s) and encode the categorical columns. The target variable (Strain_Class) should be label encoded.     [6 marks]

# %%
# label_encoder object
label_encoder =LabelEncoder()
# Encode labels in column. 
df1['Strain_Class']= label_encoder.fit_transform(df1['Strain_Class'])
df1.head(10)
# Out:
#   Gender Transmissibility Impact_Chance  Potassium_content  Strain_Class  \
# 0      F             HIGH          HIGH             25.355             1
# 1      M              LOW          HIGH             13.093             3
# 2      M              LOW          HIGH             10.114             2
# 3      F           NORMAL          HIGH              7.798             0
# 4      F              LOW          HIGH             18.043             1
# 5      F           NORMAL          HIGH              8.607             1
# 6      F           NORMAL          HIGH             16.275             3
# 7      M              LOW          HIGH             11.037             1
# 8      M           NORMAL          HIGH             15.171             2
# 9      M              LOW        NORMAL             19.368             3
#
#        Age_cat
# 0        young
# 1  middle-aged
# 2         aged
# 3  middle-aged
# 4        young
# 5  middle-aged
# 6        young
# 7  middle-aged
# 8         aged
# 9         aged

# %% [markdown]
# Q5i. Form a heatmap to visualize correlation between different columns. State your interpretation.              [4 marks]

# %%
df1_corr = df1.corr()
df1_corr
sns.heatmap(df1_corr)
# Out:
# <AxesSubplot:>

# %% [markdown]
# Q5j. Create a bar-graph/column chart to figure out how many people belong to each age category.        [3 marks]

# %%
df1
# Out:
#     Gender Transmissibility Impact_Chance  Potassium_content  Strain_Class  \
# 0        F             HIGH          HIGH             25.355             1
# 1        M              LOW          HIGH             13.093             3
# 2        M              LOW          HIGH             10.114             2
# 3        F           NORMAL          HIGH              7.798             0
# 4        F              LOW          HIGH             18.043             1
# ..     ...              ...           ...                ...           ...
# 195      F              LOW          HIGH             11.567             2
# 196      M              LOW          HIGH             12.006             1
# 197      M           NORMAL          HIGH              9.894             2
# 198      M           NORMAL        NORMAL             14.020             1
# 199      F              LOW        NORMAL             11.349             0
#
#          Age_cat
# 0          young
# 1    middle-aged
# 2           aged
# 3    middle-aged
# 4          young
# ..           ...
# 195        young
# 196         aged
# 197         aged
# 198        young
# 199        young
#
# [195 rows x 6 columns]

# %% [markdown]
# Q5k. Place the independent variables in X. Place the dependent variable (strain_class) in Y. Then split the dataset into training and testing parts (80% training; 20% testing).                       [3 marks]

# %% [markdown]
# Q5l. Utilize RandomForest and kNN to build the classification model. Based on F-measure/F1-score and Accuracy determine which model is better.								                                                    [4+4+2=10]

# %% [markdown]
# Q5m. Taking the last digit of your roll number (If your roll number is '025001', the last digit is 1. If the last digit value is greater than 5, then consider the value as 4) as the number of components, do a Principal Component Analysis (PCA) on the same data. Create a RandomForestClassifier on the transformed data and check if there is any improvement of performance.                           [5 marks]
